# %% [markdown]
# <h1>Defining Counting Probabilities</h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # What is the probability of each word?
#
# Which word do you think will have the highest probabilty?
#
# <b>Vocabulary:</b>
#
# - a
# - the
# - perfectly
# - ordinary
# - on
#
# We want to estimate the probability of each word
#
# <b> Probabilities </b>
#
# Sum up all the words in the corpus and sum up the number of times a word occurs in the corpus and divide
# <b> probability of A </b>
#
# A = count_A(11)/ total_tokens(150)
# A = 11/150 ~= .073 -> Probability
#
# <b> Probability of ordinary given my previous word was perfectly </b>
#
# We need to take into the account the previous word"
#
# If I tell you the previous word was perfectly, which word is more likely to come after perfectly, Ordinary or perfectly?
#
# Perfectly would modify and adjective or verb where "A" is not an adjective or verb
# It's more likely that perfectly would modify the word ordinary, so ordinary is more likely
#
# <b> What is probability? </b>
#
# - likelihood of an event occuring
# - range between 0 and 1
# - probabilites of all mutually exclusive events sum to 1
#
# # Random Variables
#
# We defined a random variable that can take on different values. These values are the words in the vocab that we defined above.
#
# The random variable takes that value to compute in a probability
#
# Let's say we have a vocab that contains 5 words
#
# Vocabulary:
# -    a
# -    the
# -    perfectly
# -    ordinary
# -    on
#
# All of these values are mutually exclusive, the random variable can take on each of those values
#
# # Probability Distribution
#
# Defines the probability of each value for each random variable
#
# This distribution will assign a probability to each word that is between 0 and 1 and the sum of all values will be equal to one. What do I mean? Let's hop into the example.
#
# Our random variable will take on 5 different values of our vocabulary
#
# Vocabulary:
# -    a
# -    the
# -    perfectly
# -    ordinary
# -    on
#
# # Random probabilty distribution for example vocab
#
# <b>Probability Distribution of Vocabulary:</b>
#
# -      a = .2
# -    the = .2
# -    perfectly = .2
# -    ordinary = .2
# -    on = .2
#
# <.2, .2, .2, .2, .2> -> sum = 1
#
# 5 * .2 = 1 -> which is the law of a probability distribution
#
# each probability distribution is between 0 and 1
#
# Observe that this is not a good probability distribution because the english language has a lot more words than 5 and this probabilty distribution assumes that all words have an equal chance of appearing.
#
# <b>What does it mean?</b>
#
# -      a = .2
# -    the = .2
# -    perfectly = .2
# -    ordinary = .2
# -    on = .2
#
# <.2, .2, .2, .2, .2> -> sum = 1
#
# We are saying that in any given sentence the chances that I see "a" and the chances that I see "ordinary" or "on" or any other word, will be just as likely. Well that is not true based off the english language. We are more likely to see the word "a" more than "ordinary" in any given sentence.
#
# <b>Let's get a better distribution</b>
#
# -      a = .4
# -    the = .3
# -    perfectly = .1
# -    ordinary = .1
# -    on = .1
#
# <.4, .3, .1, .1, .1> -> sum = 1
#
# <b>Analysis:</b>
#
# What does this distribution mean? Well this is a better distribution because it reflects what we noticed earlier. There is more of a chance that the word "a" will appear than "on" or ordinary. There are infinite amount of ways to arrange the probability distribution of these words.
#
# We can actually come up with a more principled way to do this. So what would be the probability distribution of the training corpus that we have above?
#
# <b> General way to calculate probability distribution</b>
#
# -      a = Count(A)/Total_Tokens(N)
# -   the = Count(the)/Total_Tokens(N)
# -    perfectly = Count(perfectly)/Total_Tokens(N)
# -    ordinary = Count(ordinary)/Total_Tokens(N)
# -    on = Count(on)/Total_Tokens(N)
#
# # Cloud With A Chance of Meteor Showers?
#
# <b> Predicting the weather with discrete random probability </b>
#
# Let's say there are three types of weather transitions:
#
# - sunny
# - cloudy
# - rain
# - meteor storm
#
# <b> New York Distribution: </b>
#
# - sunny = .3
# - cloudy = .2
# - rain = .3
# - meteor storm = .2
#
# <.3, .2, .3, .2> -> sum = 1
#
#
# <b> California Distribution: </b>
#
# - sunny = .4
# - cloudy = .2
# - rain = .2
# - meteor storm = .2
#
# <.4, .2, .2, .2> -> sum = 1
#
# # Joint Probability
#
# Probability assignment to all combinations of values of random variables
#
# Marginalization is summing the values of a column or row to find the probability of an event.
#
# <b> Joint probability Example </b>

# %% [markdown]
# ![Screenshot%202020-10-31%20183947.png](attachment:Screenshot%202020-10-31%20183947.png)

# %% [markdown]
# <b> Joint probability table analysis </b>
#
# - What's the p(cavity^toothache)? ('^' stands for "and")
#
#         Ans: .04
#
# - What's the p(cavity^¬toothache)?  ('¬' stands for "not symbol")
#
#         Ans: .06
#
# We can calculate the probability of a cavity, ¬cavity , toothache, and ¬toothache:
#
# - What's the p(cavity)?
#
#         Ans: 0.04 + 0.06 = 0.10
#
# - What's the p(¬cavity)?
#
#        Ans: 0.01 + 0.89 = .90
#
# - What's the p(toothache)?
#
#         Ans: .04 + 0.01 = 0.05
#
# - What's the p(¬toothache)?
#
#         Ans: 0.06 + 0.89 = 0.95
#
# Notice that since these events (cavity and toothache are mutually exclusive) we say that the sum of each individual event sums to 1.
#
# p(cavity) + p(¬cavity) = 1
# p(toothache) + p(¬toothache) = 1
#
# <b> Note: This is a boolean distribution </b>
#
# What do I mean?
# Boolean distribution values are 0 and 1.
#
# <b>Boolean Distribution For Toothache </b>
#
#     p(toothache = 0) = 0.06 + 0.89 = 0.95
#     p(toothache = 1) = .04 + 0.01 = 0.05
#
# So if I were to ask you what's the probability that having a toothace is false your answer should be?....
#
# - 0.95
#
# This is because p(toothache = 0) means the probability of a toothache being false
#
# <b> Notation </b>
#
# P(AvB) = P(A) + P(B) - P(A^B)

# %% [markdown]
# ![Screenshot%202020-10-31%20183947.png](attachment:Screenshot%202020-10-31%20183947.png)

# %% [markdown]
# # Conditional Probability
# <b> Formula: P(A|B) = P(A^B)/P(B) </b>
#
# Using the joint probability table
#
#     P(cavity|toothache) = 0.04 / 0.05 = 0.8
#     P(cavity|toothache) = P(Cavity ^ toothache)/P(toothache) = 0.04 / 0.05 = 0.08

# %% [markdown]
# # Review Notation

# %% [markdown]
# ![review.png](attachment:review.png)

# %% [markdown]
# # Product Rule
#
# We need conditional probabilty to use the product rule, which means we need a probabilty table
#
# - Conditional Probability:
#
#         P(A|B) = P(A^B)/P(B) (joint probability of A and B divided by the probability of B)
#         P(B|A) = P(A^B)/P(A) (same as the first)
#
# - Product Rule:
#
#         P(A^B) = P(A|B) * P(B) (conditional probability of A and B times the probability of B)
#         P(A^B) = P(A) * P(B|A) (reverse of first)
#
# <b> Note: </b> These are variations that ultimately mean the same thing

# %% [markdown]
# # Bayes' Rule
#
# - Uses the conditional probability formula.
#
# - Bayes conditional probability distributions:
#
#     Bayes rule states that if you want to find the conditional probability of h given e, your have to have the
#     conditional probability of e given h
#
#     <b>Bayes Rule:</b> P(h|e) = P(e|h) * P(h) / P(e)
#
#     <b>Conditional probabilty:</b> P(A|B) = P(A^B)/P(B)
#
#     <b>Product rule:</b> P(A^B) = P(A|B) * P(B)
#
#
# - Additional conditioning information:
#
#     P(h|e^k) = P(h|k) / P(e|k)
