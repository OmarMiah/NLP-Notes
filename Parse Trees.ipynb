# %% [markdown]
# # why is parsing difficult?
#
# - syntactic ambiguity:
#     - multiple parse trees for a given sentence
#
# - Program to promote saftey in trucks and vans
# - we can understand this with background knowledge
#
# - valid parse tree using cfg in english
#
# ![ambiguity%20in%20parse%20trees%20.png](attachment:ambiguity%20in%20parse%20trees%20.png)
#
# The first one is more likely will he was in the car which is inside the car
#
# generate every possible parse tree
#
# which is the most likely parse tree
